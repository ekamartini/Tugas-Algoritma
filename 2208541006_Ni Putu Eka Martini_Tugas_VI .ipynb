# %% [markdown]
# # 5.21 Pandas

# %% [markdown]
# Pandas merupakan Library pada Python yang digunakan pada data analisis.Tahap pertama perlu dilakukan pemanggilan Library

# %%
#============================================================
#Latihan mengenai Numpy atau numeric Python
#Pemanggilan library Pandas
#============================================================
#Pemanggilan library Pandas dilakukan karena Pandas menyediakan berbagai fitur dan agar terbaca oleh sistem
#berikut merupakan kode untuk pemanggilan library Pandas

import pandas as pd

# %% [markdown]
# ## 5.21.1 Membaca File Data pada Pandas

# %% [markdown]
# Ada beberapa format file data yang dapat dibaca oleh Pandas seperti .txt,.xlsx, dan .csv

# %% [markdown]
# #### Memanggil Data menggunakan Link

# %%
#============================================================
#Latihan Membaca File Data pada Pandas
#Memanggil atau Membaca File dengan menggunakan Link (format .csv)
#============================================================

#Langkah-langkah mengenai membaca data menggunakan link
#Pertama, buat variabel nama data. Misalkan 'bunga_iris'
#Kedua, buat code pd.read_(jenis file). Jenis File disini kita bisa gunakan jenis .csv, .txt, ataupun .xlsx
#Selanjutnya copy link raw dari github atau sumber data. dalam kasus ini saya mengambil dari repository github 
bunga_iris = pd.read_csv ('https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/bunga_iris.csv')
#Kemudian, data akan tersimpan di dalam data.csv
print (bunga_iris)
#Data akan ditunjukkan dengan menggunakan perintah print
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#data diatas juga dapat dipanggil dengan mengetik atau memanggil nama data atau variabelnya saja
bunga_iris
#dengan perintah ini, saya merasa hasil yang dikeluarkan akan lebih rapi dibandingkan dengan menggunakan perintah print
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #### Memanggil Data dalam Folder yang Sama

# %%
#============================================================
#Latihan Membaca File Data pada Pandas
#Memanggil atau Membaca File dalam Folder yang Sama
#============================================================

#Langkah-langkah membaca data dalam folder yang sama
#Pertama,simpan data dalam folder yang sama dengan project jupyter notebook
#Kedua, pastikan file data sudah tersimpan dalam folder yang sama dengan project Jupiter Notebook
#Ketiga, panggil data dengan fungsi read
bunga_iris = pd.read_csv ('bunga_iris.csv')
#Kemudian, data akan tersimpan di dalam data.csv
print (bunga_iris)
#Data akan ditunjukkan dengan menggunakan perintah print
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#Sama seperti memanggil data menggunakan link, data juga dapat dipanggil dengan mengetik nama data atau variabelnya saja
bunga_iris
#dengan perintah ini, saya merasa hasil yang dikeluarkan akan lebih rapi dibandingkan dengan menggunakan perintah print
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 5.21.2 Properti pada Pandas

# %%
#============================================================
#Properti pada Pandas
#Fungsi Head
#============================================================

#kita dapat memanggil data baris tertentu
#Gunakan fungsi head () untuk memanggilkan beberapa data pertama
bunga_iris.head (3)

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#Output yang dihasilkan adalah baris dengan indeks ke-0 sampai dengan 2 
#atau 3 baris pertama dalam data
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2

# %%
#Apabia kita tidak mengisi angka dalam fungsi head(), sistem akan menunjukkan 5 data pertama dalam data bunga_iris
bunga_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#Atau, kita bisa menggunakan perintah print seperti di bawah ini
bunga_iris.head (3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2

# %%
#============================================================
#Properti pada Pandas
#Fungsi Columns
#============================================================

#Fungsi Cloumns digunakan untuk menampilkan daftar nama kolom dalam sebuah data
#Ini berguna untuk memastikan bahwa data telah terbaca dengan benar dan untuk memahami struktur data yang digunakan dalam analisis lebih lanjut.
bunga_iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
#============================================================
#Properti pada Pandas
#Mencetak beberapa data
#============================================================
bunga_iris['sepal length (cm)']
#dengan menggunakan perintah diatas, sistem kan mencetak semua nilai yang berada dalam kolom 'sepal length (cm)'
#Output yang diasilkan adalah satu kolom berisi nilai-nilai yang ada dalam kolom 'sepal length (cm)'
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
print (bunga_iris['sepal width (cm)'][1])
#dengan maenambahkan indeks di belakang nama kolom, sistem akan menunjukkan nilai dari baris dari kolom yang diinginkan oleh user
#pada kode ini sistem akan mengambil data pada baris ke-2 pada kolom sepal width (cm)
# Out:
# 3.0

# %%
print (bunga_iris['sepal width (cm)'][1:6])
#dengan menambahkan batas di belakang nama kolom, sistem akan menampilkan data ada baris tertentu yang berada dalam kolom yang diinginkan
#pada kode ini, sistem akan mencetak nilai pada baris ke-2 hingga ke-5 dari kolom 'sepal width (cm)' dan mencetaknya
# Out:
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# 5    3.9
# Name: sepal width (cm), dtype: float64

# %%
bunga_iris[['petal length (cm)','petal width (cm)']][1:5]
#Perintah diatas akan menampilkan nilai pada kolom 'petal length (cm)' dan 'petal width (cm)' dari baris ke 2 atau indeks ke 1 sampai ke 6 atau indeks ke 5 dari data bunga_iris
# Out:
#    petal length (cm)  petal width (cm)
# 1                1.4               0.2
# 2                1.3               0.2
# 3                1.5               0.2
# 4                1.4               0.2

# %%
#============================================================
#Properti pada Pandas
#Mencetak beberapa data
#============================================================
print(bunga_iris.iloc[2])
#pada perintah ini kita akan menggunakan fungsi print untuk mencetak baris ke-2 dari data set bunga iris yang telah ternuat dalam variabel
#Fungsi '.iloc[2]' digunakan untuk memilih baris ke-2 dari data set
#Hal ini berarti kita akan mencetak data pada baris kedua secara keseluruhan dari tabel
# Out:
# sepal length (cm)    4.7
# sepal width (cm)     3.2
# petal length (cm)    1.3
# petal width (cm)     0.2
# Name: 2, dtype: float64

# %%
#============================================================
#Properti pada Pandas
#Menmfilter baris pada data frame
#fungsi loc
#============================================================

#Fungsi loc digunakan untuk memilih baris pada data set berdasarkan kondisi tertentu
(bunga_iris.loc[bunga_iris['sepal length (cm)']== 5.1])
#Dalam hal ini, kondisinya adalah nilai pada 'sepal length (cm)' sama dengan 5.1
#Ketika kode dieksekusi, outputnya adalah mendapatkan subset dari dataset 'bunga_iris' dengan isi baeis-baris
#baris-baris tersebut berisi nilai pada kolom 'sepal length' sama dengan 5.1
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.1               3.5                1.4               0.2
# 17                5.1               3.5                1.4               0.3
# 19                5.1               3.8                1.5               0.3
# 21                5.1               3.7                1.5               0.4
# 23                5.1               3.3                1.7               0.5
# 39                5.1               3.4                1.5               0.2
# 44                5.1               3.8                1.9               0.4
# 46                5.1               3.8                1.6               0.2
# 98                5.1               2.5                3.0               1.1

# %% [markdown]
# ## 5.21.3 Mengurutkan Data pada Pandas

# %%
#============================================================
#Latihan Mengurutkan Data pada Pandas
#Mencetak berdasarkan nilai pada kolom tertentu
#.sort_values
#============================================================
bunga_iris.sort_values ('sepal width (cm)')
#perintah 'sort.values' akan mengurutkan baris dari terkecil ke yang terbesar (ascending) berdasarkan nilai dari kolom 'sepal width (cm)'
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 60                 5.0               2.0                3.5               1.0
# 62                 6.0               2.2                4.0               1.0
# 119                6.0               2.2                5.0               1.5
# 68                 6.2               2.2                4.5               1.5
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 16                 5.4               3.9                1.3               0.4
# 14                 5.8               4.0                1.2               0.2
# 32                 5.2               4.1                1.5               0.1
# 33                 5.5               4.2                1.4               0.2
# 15                 5.7               4.4                1.5               0.4
#
# [150 rows x 4 columns]

# %%
#Kita juga dapat menggunakan parameter 'ascending=False' untuk mengurutkan baris dari nilai terbesar ke terkecil bedasarkan nilai dari kolom tertentu
bunga_iris.sort_values ('sepal width (cm)', ascending=False)
#Pada kode diatas, data tersebut akan diurutkan berdasarkan nilai yang ada pada kolom 'sepal width' dengan urutan dari yang terbesar ke yang terkecil
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 15                 5.7               4.4                1.5               0.4
# 33                 5.5               4.2                1.4               0.2
# 32                 5.2               4.1                1.5               0.1
# 14                 5.8               4.0                1.2               0.2
# 16                 5.4               3.9                1.3               0.4
# ..                 ...               ...                ...               ...
# 87                 6.3               2.3                4.4               1.3
# 62                 6.0               2.2                4.0               1.0
# 68                 6.2               2.2                4.5               1.5
# 119                6.0               2.2                5.0               1.5
# 60                 5.0               2.0                3.5               1.0
#
# [150 rows x 4 columns]

# %%
bunga_iris.sort_values (['sepal length (cm)', 'petal length (cm)'])
#dengan menggunakan perintah diatas, kita dapat mengurutkan baris dalam data berdasarkan nilai dari beberapa kolom yang telah ditentukan
#Dalam data ini kita akan mengurutkan baris dalam data iris tersebut berdasarkan nilai pada kolom 'sepal length (cm)' terlebih dahulu dari nilai yang terkecil ke nilai yang terbesar
#Kemudian, untuk baris yang mimiliki nilai yang sama pada kolom 'sepal length(cm)' akan diurutkan berdasarkan nilai pada kolom 'petal length (cm)' secara menaik atau dari terkecil ke nilai yang terbesar juga
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 38                 4.4               3.0                1.3               0.2
# 42                 4.4               3.2                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 135                7.7               3.0                6.1               2.3
# 117                7.7               3.8                6.7               2.2
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %% [markdown]
# ## 5.21.4 Mengubah Data pada Pandas

# %%
#============================================================
#Latihan Mengubah Data pada Pandas
#Menambah kolom 
#============================================================

bunga_iris ['tiga kali sepal length (cm)'] = 3*bunga_iris ['sepal length (cm)']
#kode diatas menumberi instruksi bahwa kita akan menambahkan kolom baru pada data set.
#Nama kolom tersebut diberi nama dengan 'tiga kali sepal length (cm)'
#nilainya akan dihitung sebagai sepal length (cm) dikalikan dengan 3
(bunga_iris)
#ketika kode ini dieksekusi, data set bunga iris akan memiliki sebuah kolim baru dengan nama 'tiga kali sepal length(cm)'
#nilainya setaraa denagan 3 kali pada kolom 'sepal length (cm)' di setiap barisnya
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      tiga kali sepal length (cm)
# 0                           15.3
# 1                           14.7
# 2                           14.1
# 3                           13.8
# 4                           15.0
# ..                           ...
# 145                         20.1
# 146                         18.9
# 147                         19.5
# 148                         18.6
# 149                         17.7
#
# [150 rows x 5 columns]

# %%
#============================================================
#Latihan Mengubah Data pada Pandas
#Menghapus kolom
#fungsi drop
#============================================================

#fungsi drop akan menghapus kolom yang diinginkan oleh pengguna
bunga_iris = bunga_iris.drop(columns=['tiga kali sepal length (cm)'])
#Ketika kode tersebut dieksekusi, fungsi drop akan menghapus kolom yang telah ditentukan dengan argumen 'columns'
#sehingga dalam hal ini, kolom 'tiga kali sepal length (cm)' akan dihapus dari data frame
bunga_iris
#dilakukan pencetakan dan pemanggilan data set kembali
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#============================================================
#Latihan Mengubah Data pada Pandas
#Menambah kolom
#============================================================
bunga_iris['Perbandingan Petal'] = bunga_iris ['petal length (cm)'] // bunga_iris['petal width (cm)']
#Kode diatas akan membuat kolom baru pada DataFrame bunga_iris yang akan dinamai 'Perbandingan Petal'
#KOlom tersebut berisi perbandingan atau hasil pembagian yang telah dibulatkan antara nilai kolom 'petal length (cm)' dengan kolom 'petal width (cm)'
(bunga_iris)
#Selanjutnya dilakukan pemanggilan dataFrame kembali

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#Dengan membuat kolom baru ini, kita dapat memperoleh informasi baru perbandingan panjang dan lebar kelopak bunga
#Rasio panjang terhadap lebar dapat memberikan informasi mengenai bentuk dan proporsi kelopak
#Hal ini dapat mempermudah pengelompokkan bunga berdasarkan karakteristik morfologinya
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Perbandingan Petal
# 0                   6.0
# 1                   6.0
# 2                   6.0
# 3                   7.0
# 4                   6.0
# ..                  ...
# 145                 2.0
# 146                 2.0
# 147                 2.0
# 148                 2.0
# 149                 2.0
#
# [150 rows x 5 columns]

# %%
#============================================================
#Latihan Mengubah Data pada Pandas
#Mengembalikan data
#============================================================

#Metode drop digunakan untuk menghapus kolom atau baris dari DataFrame
#Parameter colums menentukan bahwa kita ingin menghapus kolom pada output
bunga_iris = bunga_iris.drop(columns=['Perbandingan Petal'])
#Perintah diatas aan menghaous kolom dan label 'Perbandingan Petal' dalam daftar menunjukan kolom yang ingin dihapus
(bunga_iris)
#Dilakukan pemanggilan dataFrame yang baru. hasilnya akan sama seperti data bunga_iris yang asli
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
bunga_iris['Pebandingan Petal']=bunga_iris.iloc[:,3:8].sum(axis=1)
#Kode diatas akan menghitung jumlah kolom ke-3 hingga kolom ke-6 pada objek DataFrame Pandas dari 'bunga_iris'
#hasil akan ditempatkan pada kolom bernama perbandingan Petal pada data frame yang sama
bunga_iris
#dilskuksn pencetakan sehingga kolom baru perbandingan petal berisi jumlah nilai dari kolom ke-3 hingga ke-6 pada setiap baris dari data Frame
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Pebandingan Petal
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 5 columns]

# %%
bunga_iris['sepal length (cm)'] = bunga_iris['sepal length (cm)'].replace(['None'], 5.1)
bunga_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Pebandingan Petal
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 5.21.5 Menyimpan Data menggunakan Pandas

# %%
#============================================================
#Latihan Menyimpan Data menguunakan Pandas
#Menyimpan dengan format .txt
#============================================================

#Metode 'to.csv()' dari pandas digunakan untuk menyimpan DataFrame menjadi file CSV
bunga_iris.to_csv('data_iris_terbaru.txt', index=False, sep='\t')
#pada kode diatas, metode 'to_csv' dipanggil dengan 3 parameter
#'data_iris_terbaru.txt' sebagai nama dari file output
#'index=False' untuk mengecualikan index dari DataFrame pada output file
#'sep='\t' sebagai pemisah kolom (delimiter) antara nilai-nilau dalam daya frame. Pada kasus ini, pemisah kolom yang digunakan adalah tanda tab ('\t')
#Dengan menjalankan kode diatas, file akan tersimpan dalam direktori kerja dengan nilai-nilai dari DataFrame telah diubah dan diproses

# %%
#============================================================
#Latihan Menyimpan Data menguunakan Pandas
#Menyimpan dengan format .xlsx
#============================================================

#Metode 'to.csv()' dari pandas digunakan untuk menyimpan DataFrame menjadi file CSV
bunga_iris.to_excel('data_iris_terbaru.xlsx', index=False)
#pada kode diatas, metode 'to_csv' dipanggil dengan 2 parameter
#'data_iris_terbaru.xlsx' sebagai nama dari file output
#'index=False' untuk mengecualikan index dari DataFrame pada output file
#Dengan menjalankan kode diatas, file akan tersimpan dalam direktori kerja dengan nilai-nilai dari DataFrame telah diubah dan diproses

# %%
#============================================================
#Latihan Menyimpan Data menguunakan Pandas
#Menampilkan data
#============================================================

bunga_baru = pd.read_excel('data_iris_terbaru.xlsx')
#Kode diatas digunakan untuk membaca file terbaru yang telah disimpan sebelumnya menggunakan metode 'read_excel()'
#Dengan menjalankan kode diatas, DataFrame bunga_baru akan menampilkan nilai yang sama dengan bunga_iris sebelum disimpan dalam file baru
#Namun, karena telah dilakukan beberapa prose pengolahan sebelumnya, kemungkinan nilai-nilai dalam 'bunga_baru' akan berbeda dengan nilai awal dari bunga_iris
bunga_baru
#Dengan menjalankan kode diatas, file akan tersimpan dalam direktori kerja dengan nilai-nilai dari DataFrame telah diubah dan diproses
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Pebandingan Petal
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 5 columns]

# %%
bunga_baru2 = pd.read_csv ('data_iris_terbaru.txt',delimiter='\t')
#Kode diatas digunakan untuk membaca file dengan menggunakan fungsu 'read_csv()'dari Pandas dan menyimpannya ke dalam DataFrame baru 'bunga_baru2'
#Parameter 'delimiter='\t' digunakan untuk menunjukkan bahwa delimiter dalam file yang dibaca adalah tab ('\t')
bunga_baru2
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Pebandingan Petal
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 5.21.6 Menyaring Data menggunakan Pandas

# %%
#============================================================
#Latihan Menyaring Data menguunakan Pandas
#Fungsi .loc
#============================================================

bunga_iris.loc[bunga_iris['sepal length (cm)']== 6.7]
#Kode diatas digunakan untuk mencari baris di DataFrame 'bunga_iris' yang memiliki nilai kolom 'sepal length (cm)' = 6.7 menggunakan metode '.loc[]'
#Dengan menjalankan kode diatas, baris dengan nilai kolom 'sepal length(cm)' = 6.7 akan ditampilkan. 
#Jika tidak ada baris yang sesuai, tidak akan ada data yang ditampilkan
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 65                 6.7               3.1                4.4               1.4
# 77                 6.7               3.0                5.0               1.7
# 86                 6.7               3.1                4.7               1.5
# 108                6.7               2.5                5.8               1.8
# 124                6.7               3.3                5.7               2.1
# 140                6.7               3.1                5.6               2.4
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
#
#      Pebandingan Petal
# 65                 1.4
# 77                 1.7
# 86                 1.5
# 108                1.8
# 124                2.1
# 140                2.4
# 144                2.5
# 145                2.3

# %%
bunga_iris.loc[(bunga_iris['sepal length (cm)']== 4.6) &
                (bunga_iris['petal width (cm)'] == 0.2)]
#Kode diatas digunakan untuk mencari baris DataFrame 'bunga_iris' yang memiliki nilai 'sepal length (cm) ' = 4.6 dan kolom 'petal width(cm)' = 0.2 dengan metode '.loc[]'serta operator logika 'dan' atau &
#Dengan menjalankan kode di atas, baris yang memiliki nilai 'sepal length (cm) ' = 4.6 dan kolom 'petal width(cm)' = 0.2 akan ditampilkan oleh sistem
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 3                 4.6               3.1                1.5               0.2
# 22                4.6               3.6                1.0               0.2
# 47                4.6               3.2                1.4               0.2
#
#     Pebandingan Petal
# 3                 0.2
# 22                0.2
# 47                0.2

# %%
bunga_iris.loc[(bunga_iris['sepal length (cm)']== 5.0) &
                (bunga_iris['petal width (cm)'] == 0.2) &
                (bunga_iris['sepal width (cm)'] > 3.3)]
#Kode di atas digunakan untuk mencari baris di DataFrame 'bunga_iris' yang memiliki nilai kolom 'sepal length (cm)' sama dengan 5.0, kolom 'petal width (cm)' sama dengan 0.2, dan kolom 'sepal width (cm)' lebih besar dari 3.3 menggunakan metode .loc[] dari Pandas dengan operator logika & (dan)
#Ketika kode dijalankan, baris yang memenuhi syarat akan ditampilkan oleh sistem
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 4                5.0               3.6                1.4               0.2
# 7                5.0               3.4                1.5               0.2
#
#    Pebandingan Petal
# 4                0.2
# 7                0.2

# %% [markdown]
# ## 5.21.7 Pengelompokkan Data menggunakan Pandas

# %%
#============================================================
#Mengelompokkan data menggunakan Pandas
#Perintah mean ()
#============================================================
bunga_iris.groupby(['sepal width (cm)']).mean()
#Kode diatas menggunakan metode 'groupby()' dari pandas untuk engelompokkan baris di Data Frame berdasarkan nilai dari kolom 'sepal width(cm)'
#kemudian metode 'mean()' untuk menghitung nilai rata-rata dari setiap kelompok
#Ketika kode diatas dijalankan, akan dihasilkan suatu data bru yang berisi nilai rata-rata dari setiap kolom 'bunga iris' yg sudah dikelompokkan berdasarkan nilai kolom 'sepal width (cm)'
# Out:
#                   sepal length (cm)  petal length (cm)  petal width (cm)  \
# sepal width (cm)
# 2.0                        5.000000           3.500000          1.000000
# 2.2                        6.066667           4.500000          1.333333
# 2.3                        5.325000           3.250000          0.975000
# 2.4                        5.300000           3.600000          1.033333
# 2.5                        5.762500           4.512500          1.550000
# 2.6                        6.160000           4.880000          1.420000
# 2.7                        5.855556           4.622222          1.555556
# 2.8                        6.335714           5.042857          1.707143
# 2.9                        6.060000           4.350000          1.320000
# 3.0                        6.015385           4.234615          1.403846
# 3.1                        6.036364           3.790909          1.245455
# 3.2                        5.884615           3.753846          1.261538
# 3.3                        6.016667           4.200000          1.566667
# 3.4                        5.316667           2.466667          0.716667
# 3.5                        5.150000           1.416667          0.300000
# 3.6                        5.425000           2.475000          0.750000
# 3.7                        5.266667           1.500000          0.266667
# 3.8                        6.100000           3.300000          0.900000
# 3.9                        5.400000           1.500000          0.400000
# 4.0                        5.800000           1.200000          0.200000
# 4.1                        5.200000           1.500000          0.100000
# 4.2                        5.500000           1.400000          0.200000
# 4.4                        5.700000           1.500000          0.400000
#
#                   Pebandingan Petal
# sepal width (cm)
# 2.0                        1.000000
# 2.2                        1.333333
# 2.3                        0.975000
# 2.4                        1.033333
# 2.5                        1.550000
# 2.6                        1.420000
# 2.7                        1.555556
# 2.8                        1.707143
# 2.9                        1.320000
# 3.0                        1.403846
# 3.1                        1.245455
# 3.2                        1.261538
# 3.3                        1.566667
# 3.4                        0.716667
# 3.5                        0.300000
# 3.6                        0.750000
# 3.7                        0.266667
# 3.8                        0.900000
# 3.9                        0.400000
# 4.0                        0.200000
# 4.1                        0.100000
# 4.2                        0.200000
# 4.4                        0.400000

# %%
#============================================================
#Mengelompokkan data menggunakan Pandas
#Perintah mean () dengan mengelompokkan
#============================================================
bunga_iris.groupby(['sepal width (cm)']).mean().sort_values('sepal length (cm)', ascending=True)
#Menggunakan metode 'groupby()' untuk mengelompokkan baris dalam DataFrame berdasaekan nilai 'sepal width(cm)'
#Menggunakan metode 'mean()' untuk menghitung rata-rata dari setiap kelompok.
#Menggunakan metode 'sort_values()' untuk mengurutkan data hasil kelompokkan berdasarkan kolom 'sepal length (cm)' secara menaik
#ketika kode tersebut dijalankan, output yang dihasilkan adalah data baru yang berisi nilai rata-rata dar setiap kolom yang sudah dikelompokkan berdasarkan nilai pada kolom 'sepal width (cm)
#Kemudian, data diurutkan berdasarkan kolom 'sepal length(cm)' secara menaik
# Out:
#                   sepal length (cm)  petal length (cm)  petal width (cm)  \
# sepal width (cm)
# 2.0                        5.000000           3.500000          1.000000
# 3.5                        5.150000           1.416667          0.300000
# 4.1                        5.200000           1.500000          0.100000
# 3.7                        5.266667           1.500000          0.266667
# 2.4                        5.300000           3.600000          1.033333
# 3.4                        5.316667           2.466667          0.716667
# 2.3                        5.325000           3.250000          0.975000
# 3.9                        5.400000           1.500000          0.400000
# 3.6                        5.425000           2.475000          0.750000
# 4.2                        5.500000           1.400000          0.200000
# 4.4                        5.700000           1.500000          0.400000
# 2.5                        5.762500           4.512500          1.550000
# 4.0                        5.800000           1.200000          0.200000
# 2.7                        5.855556           4.622222          1.555556
# 3.2                        5.884615           3.753846          1.261538
# 3.0                        6.015385           4.234615          1.403846
# 3.3                        6.016667           4.200000          1.566667
# 3.1                        6.036364           3.790909          1.245455
# 2.9                        6.060000           4.350000          1.320000
# 2.2                        6.066667           4.500000          1.333333
# 3.8                        6.100000           3.300000          0.900000
# 2.6                        6.160000           4.880000          1.420000
# 2.8                        6.335714           5.042857          1.707143
#
#                   Pebandingan Petal
# sepal width (cm)
# 2.0                        1.000000
# 3.5                        0.300000
# 4.1                        0.100000
# 3.7                        0.266667
# 2.4                        1.033333
# 3.4                        0.716667
# 2.3                        0.975000
# 3.9                        0.400000
# 3.6                        0.750000
# 4.2                        0.200000
# 4.4                        0.400000
# 2.5                        1.550000
# 4.0                        0.200000
# 2.7                        1.555556
# 3.2                        1.261538
# 3.0                        1.403846
# 3.3                        1.566667
# 3.1                        1.245455
# 2.9                        1.320000
# 2.2                        1.333333
# 3.8                        0.900000
# 2.6                        1.420000
# 2.8                        1.707143

# %%
#============================================================
#Mengelompokkan data menggunakan Pandas
#Perintah sum
#============================================================

bunga_iris.groupby(['sepal width (cm)']).sum()
#pada perintah diatas, dilakukan suatu pengelompokkan data pada variabel bunga_iris berdasarkan kolom 'sepal width (cm)'
#Selanjutnya dilakukan agregasi nilai dengan fungsi 'sum()' 
#dimana untuk setiap kelompok data yang dihasilkan dari pengelompokkan tersebut
#Output yang dihasilkan adalah suatu data hasil penjumlahan untuk setiap kolom dari data bunga_iris 
#dengan perhitungannya berdasarkan kelompok-kelompok yang dibentuk berdasarkan nilai unik pada kolom 'sepal width(cm)'
# Out:
#                   sepal length (cm)  petal length (cm)  petal width (cm)  \
# sepal width (cm)
# 2.0                             5.0                3.5               1.0
# 2.2                            18.2               13.5               4.0
# 2.3                            21.3               13.0               3.9
# 2.4                            15.9               10.8               3.1
# 2.5                            46.1               36.1              12.4
# 2.6                            30.8               24.4               7.1
# 2.7                            52.7               41.6              14.0
# 2.8                            88.7               70.6              23.9
# 2.9                            60.6               43.5              13.2
# 3.0                           156.4              110.1              36.5
# 3.1                            66.4               41.7              13.7
# 3.2                            76.5               48.8              16.4
# 3.3                            36.1               25.2               9.4
# 3.4                            63.8               29.6               8.6
# 3.5                            30.9                8.5               1.8
# 3.6                            21.7                9.9               3.0
# 3.7                            15.8                4.5               0.8
# 3.8                            36.6               19.8               5.4
# 3.9                            10.8                3.0               0.8
# 4.0                             5.8                1.2               0.2
# 4.1                             5.2                1.5               0.1
# 4.2                             5.5                1.4               0.2
# 4.4                             5.7                1.5               0.4
#
#                   Pebandingan Petal
# sepal width (cm)
# 2.0                             1.0
# 2.2                             4.0
# 2.3                             3.9
# 2.4                             3.1
# 2.5                            12.4
# 2.6                             7.1
# 2.7                            14.0
# 2.8                            23.9
# 2.9                            13.2
# 3.0                            36.5
# 3.1                            13.7
# 3.2                            16.4
# 3.3                             9.4
# 3.4                             8.6
# 3.5                             1.8
# 3.6                             3.0
# 3.7                             0.8
# 3.8                             5.4
# 3.9                             0.8
# 4.0                             0.2
# 4.1                             0.1
# 4.2                             0.2
# 4.4                             0.4

# %%
#============================================================
#Mengelompokkan data menggunakan Pandas
#Perintah Count
#============================================================

#perintah grupby() digunakan untuk mengelompokkan data berdasaekan nilai unik pada suatu kolom yaitu 'sepal width (cm)'
#perintah count() digunakan untuk menghitung jumlah entri data pada setiap kelompok
bunga_iris.groupby(['sepal width (cm)']).count()
#kode diatas akan menghasilkan output berupa data yang menunjukkan jumlah entri data pada setiap nilai unik pada kolom 'sepal width (Cm)'
# Out:
#                   sepal length (cm)  petal length (cm)  petal width (cm)  \
# sepal width (cm)
# 2.0                               1                  1                 1
# 2.2                               3                  3                 3
# 2.3                               4                  4                 4
# 2.4                               3                  3                 3
# 2.5                               8                  8                 8
# 2.6                               5                  5                 5
# 2.7                               9                  9                 9
# 2.8                              14                 14                14
# 2.9                              10                 10                10
# 3.0                              26                 26                26
# 3.1                              11                 11                11
# 3.2                              13                 13                13
# 3.3                               6                  6                 6
# 3.4                              12                 12                12
# 3.5                               6                  6                 6
# 3.6                               4                  4                 4
# 3.7                               3                  3                 3
# 3.8                               6                  6                 6
# 3.9                               2                  2                 2
# 4.0                               1                  1                 1
# 4.1                               1                  1                 1
# 4.2                               1                  1                 1
# 4.4                               1                  1                 1
#
#                   Pebandingan Petal
# sepal width (cm)
# 2.0                               1
# 2.2                               3
# 2.3                               4
# 2.4                               3
# 2.5                               8
# 2.6                               5
# 2.7                               9
# 2.8                              14
# 2.9                              10
# 3.0                              26
# 3.1                              11
# 3.2                              13
# 3.3                               6
# 3.4                              12
# 3.5                               6
# 3.6                               4
# 3.7                               3
# 3.8                               6
# 3.9                               2
# 4.0                               1
# 4.1                               1
# 4.2                               1
# 4.4                               1

# %%
data1.loc[data1['sepal width (cm)'].str.contains(0.9)]

# Kode tersebut akan menghasilkan error karena perintah contains hanya bisa digunakan untuk format string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27984\811484811.py in <module>
# ----> 1 data1.loc[data1['sepal width (cm)'].str.contains(0.9)]
#       2
#       3 # Kode tersebut akan menghasilkan error karena perintah contains hanya bisa digunakan untuk format string
#
# NameError: name 'data1' is not defined

# %% [markdown]
# # 5.22 Matplotlib

# %% [markdown]
# Matplotlib merupakan salah satu Library pada Python yang fungsi utamanya adalah dalam hal menggambarkan grafik, histogram dan berbagai jenis plot hasil dari pengolahan data menggunakan Library lainnya yaitu Pandas dan Numpy. Untuk itu penggunaan ketiga Library tersebut biasanya menjadi satu kesatuan.

# %%
#============================================================
#Latihan mengenai Matplotlib
#Pemanggilan library 
#============================================================
import numpy as np
#numpy adalah library untuk pemrosesan multidimensi dan operasi matematika. Dalam kasus ini diberi alias dengan np
import pandas as pd
#Pandas adalah library untuk mengelola dan menganalisis data dalam format tabel. Dalam kasus ini diberi alias dengan pd
import matplotlib.pyplot as plt
#Matplotlib adalah library untuk membuat visualisasi grafik dan plot

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#dengan membuat pemanggilan diatas, user dapat menggunakan berbagai fungsi 
#fungsi tersebut akan digunakan untuk analisis data dan visualisasi
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %% [markdown]
# ## 5.22.1 Grafik Sederhana dengan Matplotlib

# %% [markdown]
# Pada dasarnya Matplotlib berfungsi untuk memplot data menjadi grafik, histogram atau bentuk lainnya untuk mempermudah visualisasi data yang sedang diolah.

# %%
#============================================================
#Latihan mengenai Matplotlib
#Grafik sederhana
#============================================================

#diinsialisasikan variabel x dan y yang merukan list dari number yang berisi 3 nilai di dalam masing-masing variabel
x = [3,5,7]
y = [6,8,10]

#digunakan metode plot yang akan menggambar garis yang menghubungkan ketiga titik yaitu (3,6), (5,8), dan (7,10) pada bidang koordinat
plt.plot (x,y)
#Kemudian, kode dibawah digunakan untuk memberikan judul grafik yaitu grafik y = x+3
plt.title ("Grafik y = x+3")
#kemudian, sumbu x diberi label dengan kode sebagai berikut
plt.xlabel ('x')
#begitu pula dengan label pada sumbu y
plt.ylabel ('y')

#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#Output yang dihasilkan adalah sebuah grafik yang menunjukkan hubungan antara variabel x dan y
#Pada grafik diberi judul 'Grafik y = x + 3', serta label dari sumbu x dan y
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ## 5.22.2 Properti Pembuatan Grafik dengan Matplotlib

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan grafik
#============================================================
#Grafik yang dibuat akan menampilkan hubungan x dan y dalam koordinat kartesius

#diinisialisasikan variabel x dan y yang merupakan list yang berisi 9 nilai dari masing-masing variabel x dan y yang berkaitan dengan fungsi y = x^3
x = [-4,-3,-2,-1,0,1,2,3,4]
y = [-64,-27,-8,-1,0,1,8,27,64]
#Kemudian, diinisialisasikan juga variabel x1 dan y1 yang juga merupakan list yang berisi masing-masing anggota dari variabel x1 dan y1 
x1 = [1,2,3,4,5,6,7]
y1 = [-2,0,2,4,6,8,10]

#digunakan method "plt.figure" untuk menentukan ukuran dan resolusi gambar
plt.figure(figsize=(8,8), dpi =300)
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 8x8 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci

#Kemudian ditentukan font, ukuran font, serta warna dari garis dan grafik
plt.plot(x,y,label='y=x^3',color='purple',linewidth=5,marker='.',markersize =10,markeredgecolor='orange',linestyle='-')
#label='y=x^3' : dugunakan untuk memberi label atau judul pada plot
#color : digunakan untuk memberi warna pada plot
#linewidth : digunakan untuk memberi ketebalan garis pada plot
#marker : digunakan untuk menandai titik pada plot dengan bentuk titik
#markersize : digunakan untuk menentukan ukuran dari marker
#markerredgecolor : digunakan untuk memberi warna pada tepi marker
#linestyle : digunakan untuk menentukan jenis garis pada plot
plt.plot(x1,y1)
#metode ini digunakan untuk membuat plot dari data pada variabel x1 dan y1
#plot ini tidak memiliki variabel lain seperti label ataupun color sehingga plot ini akan menggunakan nilai default untuk setiap parameter
plt.title ('Grafik y =x^3', fontdict={'fontname' : 'Times New Roman', 'fontsize' :18})
#Ditentukan font dan ukuran font pada judul grafik
#'Grafik y =x^3', adalah string yang akan ditampilkan sebagai judul grafik
#fontdict : digunakan untuk mengatur jenis font dan ukuran font dari judul grafik
#fontname : jenis fnt
#fontsize : ukuran font
plt.xlabel ('x', fontdict={'fontname':'Comic Sans MS','fontsize':16})
plt.ylabel ('y', fontdict={'fontname':'Comic Sans MS','fontsize':16})
#Kemudian, sumbu x dan y diberi label pada grafik
plt.xticks ([-4,-3,-2,-1,0,1,2,3,4])
plt.yticks ([-64,-27,-8,-1,0,1,8,27,64])
#Digunakan fungsi plt.ticks untuk menentukan skala sumbu x dan t yang akan ditampilkan pada grafik
#pada sumbu x ditampilkan angka dari -4 sampai 4
#pada sumbu y ditampilkan anhka dari -64 sampai 64
plt.legend()
#metode ini digunakan untuk menampilkan legenda pada grafik yang menunjukkan label garis untuk grafik pertaman
plt.savefig('grafik.png', dpi=300)
#metode ini digunakan untuk menyimpan grafik sebagai file gambar dalam format PNG dan nama Grafik "grafik.png" dengan resolusi 300dpi
plt.show()
#Metode ini digunakan untuk menampilkan grafik pada jendela hasil

# %%
# diinisialisasikan variabel-variabel yang berisi data kolom pada dataFrame bunga_iris
x = bunga_iris['sepal length (cm)']
y = bunga_iris['petal length (cm)']
x1 = bunga_iris['sepal width (cm)']
y1 = bunga_iris['petal width (cm)']


plt.figure(figsize=(20,20), dpi=300)
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 8x8 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci



plt.plot(x,y, label = 'Grafik length' ,  color = 'yellow' , 
         linewidth = 3 , marker = '.' , markersize = 15 , 
         markeredgecolor = 'green' , linestyle='-')
#label='Grafik length' : dugunakan untuk memberi label atau judul pada plot
#color : digunakan untuk memberi warna pada plot
#linewidth : digunakan untuk memberi ketebalan garis pada plot
#marker : digunakan untuk menandai titik pada plot dengan bentuk titik
#markersize : digunakan untuk menentukan ukuran dari marker
#markerredgecolor : digunakan untuk memberi warna pada tepi marker
#linestyle : digunakan untuk menentukan jenis garis pada plot


plt.plot(x1,y1, label = 'Grafik width', marker = '*' , 
         markersize = 15 , markeredgecolor = 'red' )
#metode ini digunakan untuk membuat plot dari data pada variabel x1 dan y1
#plot ini tidak memiliki variabel lain seperti label ataupun color sehingga plot ini akan menggunakan nilai default untuk setiap parameter

# berikut penamaan koordinat dengan fungsi 'title()'
# fungsi 'title()' digunakan untuk memasukan data string dan ukuran font
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.title('Grafik Bunga Iris ', fontdict = {'fontname' : 'Times New Roman' , 'fontsize' : 15})

# berikut inisialisasi sumbu x dan y dengan penamaan menggunakan data string
# fungsi 'fontdict' digunakan untuk menentukan ukuran font
plt.xlabel('X', fontdict={'fontname' : 'Comic Sans MS' , 'fontsize' : 6})
plt.ylabel('Y', fontdict={'fontname' : 'Comic Sans MS' , 'fontsize' : 6})

# berikut pembentukan output dari label x dan y
plt.xticks(bunga_iris['sepal length (cm)'])
plt.yticks(bunga_iris['petal length (cm)'])
plt.legend()

# berikut pembentukan output dari label x1 dan y1
plt.xticks(bunga_iris['sepal width (cm)'])
plt.yticks(bunga_iris['petal width (cm)'])
plt.legend()

# berikut penyimpanan figure pada 'grafik.png' dengan resolusi 500 dpi
plt.savefig('grafik.png' , dpi=500)

# berikut fungsi 'show()' yang digunakan untuk mengeluarkan output figure
plt.show()

# %% [markdown]
# ## 5.22.3 Histogram Sederhana dengan Matplotlib

# %%
#============================================================
#Latihan mengenai Matplotlib
#Histogram Sederhana
#============================================================
#plt.bar adalah metode pada library matplotlib yang digunakan untuk membuat histogram

#diinisialisasikan sebuah list yang berisi label atau kategori yang akan ditampilkan pada sumbu x
pengguna = ['Pengguna IOS', 'Pengguna Android', 'Windows Phone']
#diinisialisasikan juga list yang berisi nilai dari data yang akan ditampilkan pada sumbu y dan panjang dari setiap bar
jumlah = [98,65,25]

#metode plt.bar akan menampilkan bar chart dengan sumbu x berisi label dari variabel pengguna 
#serta variabel y menampilkan nilai dari jumlah
plt.bar(pengguna,jumlah)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 5.22.4 Properti Pembuatan Histogram dengan Matplotlib

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan Histogram
#============================================================

#Diinisialisasikan variabel pekerjaan yang berisi list untuk menjadi label pada sumbu x
pekerjaan = ['PNS', 'Guru', 'Buruh', 'Programmer', 'Petani']
#diinisialisasikan juga variabel jumlah sebagai nilai pada sumbu y
jumlah = [180, 55, 25, 20, 80]

#digunakan method "plt.figure" untuk menentukan ukuran dan resolusi gambar
plt.figure(figsize=(8,4))
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 8x4 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci

histogram = plt.bar(pekerjaan,jumlah,color = 'orange')
#Selanjutnya kita memanggil metode untuk membuat histogram
#Kita juga dapat menentukan warna pada histogram dengan menambahan parameter color
#Variabel histogram berisi sebuah list yang berisi bar chart yang telah dibuat.
pola = ['o','x','/','.','*']
#Kita juga dapat membuat sebuah list 'pola' yang berisi simbol-simbol yang digunakan sebagai pola pada bar chart

#kemudian, kita dapat mengatur pola pada setiap bar chart dengan menggunakan metode '.set.hatch()' pada masing-masing bar chart yang ada pada variabel'histogram'
histogram [0].set_hatch('o')
histogram [1].set_hatch('x')
histogram [2].set_hatch('/')
histogram [3].set_hatch('.')
histogram [4].set_hatch('*')
plt.show()
#kode diatas dipanggil untuk menampilkan histogram yang telah dibuat

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan Histogram (2)
#============================================================

#Diinisialisasikan variabel pekerjaan yang berisi list untuk menjadi label pada sumbu x
pekerjaan = ['PNS', 'Guru', 'Buruh', 'Programmer', 'Petani']
#diinisialisasikan juga variabel jumlah sebagai nilai pada sumbu y
jumlah = [180, 55, 25, 20, 80]

#digunakan method "plt.figure" untuk menentukan ukuran dan resolusi gambar
plt.figure(figsize=(8,4))
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 8x4 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci

hist = plt.bar(pekerjaan,jumlah,color = 'silver')
#Selanjutnya kita memanggil metode untuk membuat histogram
#variabel hist sebagai objek dari diagram batang tersebut
#Kita juga dapat menentukan warna pada histogram dengan menambahan parameter color
#Variabel hist berisi sebuah list yang berisi bar chart yang telah dibuat.
pola = ['o','x','/','.','*']
#Kita juga dapat membuat sebuah list 'pola' yang berisi simbol-simbol yang digunakan sebagai pola pada bar chart


for bar in hist :
#digunakan loop 'for' untuk mengakses setiap bar pada histogram variabel hist
    bar.set_hatch(pola.pop(0))
#pada setiap bar, diatur pola dengan menggunakan set_hatch dan pola.pop(0)
#pola.pop(0) digunakan untuk mengambil dan menghapus elemen pertama dari list pola sehingga setiap bar akan memiliki pola yang berbeda
    
    
plt.show()
#kode diatas dipanggil untuk menampilkan histogram yang telah dibuat

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan Histogram (3)
#============================================================

#Diinisialisasikan variabel pekerjaan yang berisi list untuk menjadi label pada sumbu x
pekerjaan = ['PNS', 'Guru', 'Buruh', 'Programmer', 'Petani']
#diinisialisasikan juga variabel jumlah sebagai nilai pada sumbu y
jumlah = [180, 55, 25, 20, 80]

#digunakan method "plt.figure" untuk menentukan ukuran dan resolusi gambar
plt.figure(figsize=(8,4))
#figsize digunakan untuk menentukan gambar dengan format inci. sehingga pada kode ini ukuran gambar yang akan dihasilkan adalah 8x4 inci
#dpi digunakan untuk menentukan resolusi gambar dalam piksel per inci. Sehingga, pada kode ini resolusi yang dihasilkan adalah 300 piksel per inci
hist = plt.bar(pekerjaan,jumlah,color = 'pink')
#Selanjutnya kita memanggil metode untuk membuat histogram
#variabel hist sebagai objek dari diagram batang tersebut
#Kita juga dapat menentukan warna pada histogram dengan menambahan parameter color
#Variabel hist berisi sebuah list yang berisi bar chart yang telah dibuat.
pola = ['o','x','/','.','*']
#Kita juga dapat membuat sebuah list 'pola' yang berisi simbol-simbol yang digunakan sebagai pola pada bar chart

for x in [0,1,2,3,4]:
#merupakan alternatif dari kode sebelumnya yang menggunakan perulangan 'for' untuk memberikan pola berbeda pada setiap histogram
    hist[x].set_hatch(pola[x])
#dalam perulangan, setiap bar akan diakses dengan menggunakan indeks x pada list 'hist'
#setiap pola diambil dari list 'pola' menggunakan indeks yang sama
#selanjutnya, setiap bar diberikan pola yang sesuai menggunakan metode 'set_hatch()'
    
plt.show()
#kode diatas dipanggil untuk menampilkan histogram yang telah dibuat

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan Histogram (4)
#============================================================

#Pertama, dilakukan import library pandas dan matplotib
import pandas as pd
import matplotlib.pyplot as plt

#Dilakukan pembacaan data dengan menggunakan metode .read dari data dengan file yang sama
data_iris = pd.read_csv('bunga_iris.csv')

# Akan diambil kolom petal_length dari dataframe iris_data
petal_length = data_iris['petal length (cm)']

# Akan dibuat histogram dari data petal_length
plt.hist(petal_length, bins=150, color='black')
#Akan dibuat suatu plot histogram dari petal length
#bins adalah interval dari histogram yang akan dibuat
plt.xlabel('Petal Length (cm)')
#label sumbu x akan menunjukkan petal length 
plt.ylabel('Frekuensi')
#label sumbu y akan menunjukkan frekuensi nilai panjang kelopak dalam setiap interval (bin)
plt.title('Histogram Petal Length(cm)')
#dibuat judul dengan string "Histogram Petal Length(cm)"

plt.show()

# %% [markdown]
# # Program Menggunakan data iris dengan pandas dan matplotlib

# %%
#============================================================
#Latihan mengenai Matplotlib
#Properti pembuatan Scatter Plot hubungan antara Sepal Length dan Sepat Width
#============================================================

#Pertama, dilakukan import untuk library Pandas dan Matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Kemudian, kita lakukan pembacaan data dengan menggunakan metode .read_csv
iris_data = pd.read_csv('bunga_iris.csv')

#Selanjutnya dipilih kolom yang akan dimasukkan dalam gambar
#Dalam kasus ini dipilih kolom 'sepal length (cm)' dan kolom 'sepal width (cm)'
sepal_length = iris_data['sepal length (cm)']
sepal_width = iris_data['sepal width (cm)']

#Akan dibuat scatterplot, mengenai hubungan antara sepal length dan sepal width
plt.scatter(sepal_length, sepal_width)
plt.xlabel('Sepal Length (cm)')
#diberikan label sumbu x untuk merepresentasikan label yang ingin ditambahkan pada sumbu x
plt.ylabel('Sepal Width (cm )')
#diberikan label sumbu y untuk merepresentasukan label yang ingin ditambahkan pada sumbu y
plt.title('Scatter Plot dari Sepal Length (cm) dan Sepal Width (cm)')
#digunakan untuk menambahkan judul pada sactterlot dengan mengambil string Scatter Plot dari Sepal Length (cm) dan Sepal Width (cm)' sebagai argumen
plt.show
#digunakan untuk menampilkan sactter plot yang sudah diberi label dan judul agar mudah dipahami
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas as pd

# %%
#dilakukan pemanggilan data menggunakan link (Sumber : github imdwipayana)
bunga_iris = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/bunga_iris.csv')
#'bunga_iris.csv': File ini berisi data numerik tentang bunga iris, termasuk panjang dan lebar sepal dan kelopak, serta nomor baris
#File ini berisi empat kolom, masing-masing adalah 'Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)', dan 'Petal Width (cm)'.
#Setiap baris dalam file ini mewakili pengukuran pada satu bunga iris tertentu.
nama_bunga = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/DATA/main/Bunga%20Iris/nama_bunga.csv')
#'nama_bunga.csv': File ini berisi nama spesies bunga iris yang sesuai dengan setiap baris dalam file 'bunga_iris.csv'.
(bunga_iris)
(nama_bunga)
# Out:
#     flower_name
# 0        setosa
# 1        setosa
# 2        setosa
# 3        setosa
# 4        setosa
# ..          ...
# 145   virginica
# 146   virginica
# 147   virginica
# 148   virginica
# 149   virginica
#
# [150 rows x 1 columns]

# %%
bunga = pd.merge(bunga_iris,nama_bunga,left_index=True,right_index=True)
#Perintah di atas menggabungkan dua dataframe bunga_iris dan nama_bunga berdasarkan index atau nomor barisnya.
#Perintah ini menggunakan fungsi merge()
#Argumen left_index=True dan right_index=True menunjukkan bahwa penggabungan dilakukan berdasarkan index atau nomor baris di kedua dataframe tersebut.
#Kemudian hasil penggabungan disimpan dalam variabel 'bunga'

# %%
bunga
#berikut penggabungan yang dihasilkan
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#     flower_name
# 0        setosa
# 1        setosa
# 2        setosa
# 3        setosa
# 4        setosa
# ..          ...
# 145   virginica
# 146   virginica
# 147   virginica
# 148   virginica
# 149   virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
#Seaborn adalah sebuah library Python untuk visualisasi data yang dibangun di atas Matplotlib
#disini saya mencoba menggunakan library seaborn

# %%
#menggunakan library Seaborn untuk membuat plot yang menampilkan hubungan antara semua pasang variabel dalam dataset bunga
sns.pairplot(bunga,hue='flower_name')
#Fungsi pairplot() Seaborn digunakan untuk membuat plot pasangan. 
#Argumen hue digunakan untuk membagi plot scatter matrix menjadi beberapa grup dengan warna yang berbeda untuk setiap grup.
#Dengan menggunakan pairplot(), kita dapat melihat hubungan antara variabel-variabel dalam dataset dan juga membandingkan pola yang muncul antara tiga spesies bunga iris yang berbeda.
